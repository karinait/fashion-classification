# %%
import os
import zipfile
import requests
import glob
import sys
import re
import time

import warnings
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from PIL import Image

from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input as mobile_preprocess_input
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import decode_predictions as mobile_decode_predictions
from tensorflow.keras.applications.inception_v3 import preprocess_input as inception_preprocess_input
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import decode_predictions as inception_decode_predictions

from tensorflow.keras.callbacks import ModelCheckpoint, Callback
from tensorflow.keras.mixed_precision import set_global_policy
from tensorflow.keras import regularizers


# %matplotlib inline
# Out:
# 2024-12-29 22:16:47.538440: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735528607.559726   50145 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735528607.566356   50145 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-29 22:16:47.599295: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Getting python version
print(sys.version)
# Out:
# 3.12.3 (main, Nov  6 2024, 18:32:19) [GCC 13.2.0]

# %%
#Getting tensorflow version
tf.__version__
# Out:
# '2.18.0'

# %%
#Checking that Tensorflow detects a GPU
gpus = tf.config.list_physical_devices('GPU')
print("GPUs Available:", gpus)
# Out:
# GPUs Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
if gpus:
    try:
        # Restrict TensorFlow to only allocate memory as needed
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
# Check if the TF_GPU_ALLOCATOR environment variable is set
gpu_allocator = os.environ.get('TF_GPU_ALLOCATOR')

if gpu_allocator is None:
    print("Warning: The TF_GPU_ALLOCATOR environment variable is not set. This variable determines how TensorFlow manages GPU memory allocation."
          "Setting it to 'cuda_malloc_async' can improve performance on NVIDIA GPUs by reducing memory fragmentation during model training. "
          " Please consider setting the variable before running the model (export TF_GPU_ALLOCATOR=cuda_malloc_async)")
else:
    print(f"TF_GPU_ALLOCATOR is set to: {gpu_allocator}")
# Out:
# TF_GPU_ALLOCATOR is set to: cuda_malloc_async

# %%
#set mixed precision policy
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %%
#setting seeds
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %%
#hide some warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
# Start timer to measure execution time
start_time = time.time()

# %% [markdown]
# # Download images to train our model

# %%
DATASET_DIR = '../dataset/fashion-product-images-dataset/'
ZIP_FILE_PATH = os.path.join(DATASET_DIR, 'fashion-product-images-small.zip')
DOWNLOAD_URL = 'https://www.kaggle.com/api/v1/datasets/download/paramaggarwal/fashion-product-images-dataset'

# %%
def is_empty_directory(directory):
    return not os.path.exists(directory) or not os.listdir(directory)

# %%
if is_empty_directory(DATASET_DIR):
    print("Empty dataset directory. Downloading ZIP File from Kaggle...")
    
    response = requests.get(DOWNLOAD_URL, allow_redirects=True)
    with open(ZIP_FILE_PATH, 'wb') as file:
        file.write(response.content)
    print("Download completed.")

    # Extract the ZIP file
    with zipfile.ZipFile(ZIP_FILE_PATH, 'r') as zip_ref:
        zip_ref.extractall(DATASET_DIR)
    print("ZIP file extracted.")

    # Delete the ZIP file after extraction
    os.remove(ZIP_FILE_PATH)
else:
    print("The are images already downloaded. No need to download Zip file from Kaggle")
# Out:
# Empty dataset directory. Downloading ZIP File from Kaggle...

# %% [markdown]
# # EDA

# %%
#Load an image
image_path = f'{DATASET_DIR}/images/'
fullname = f'{image_path}/10009.jpg'
img=load_img(fullname, target_size=(224,224))

# %%
x=np.array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
## Reading informacion about images
CSV_FILE_PATH = F'{DATASET_DIR}/styles.csv'

# %%
# Read the first few rows of the CSV to inspect its structure
preview_data = pd.read_csv(CSV_FILE_PATH, nrows=5)
print(preview_data.head())
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#    year   usage                             productDisplayName
# 0  2011  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012  Casual             Peter England Men Party Blue Jeans
# 2  2016  Casual                       Titan Women Silver Watch
# 3  2011  Casual  Manchester United Men Solid Black Track Pants
# 4  2012  Casual                          Puma Men Grey T-shirt

# %%
#read dataset and skip some bad lines
columns=['id', 'gender', 'masterCategory', 'subCategory', 'articleType', 'productDisplayName']
data = pd.read_csv(CSV_FILE_PATH,  usecols=columns, on_bad_lines='skip')
data.head()
# Out:
#       id gender masterCategory subCategory  articleType  \
# 0  15970    Men        Apparel     Topwear       Shirts
# 1  39386    Men        Apparel  Bottomwear        Jeans
# 2  59263  Women    Accessories     Watches      Watches
# 3  21379    Men        Apparel  Bottomwear  Track Pants
# 4  53759    Men        Apparel     Topwear      Tshirts
#
#                               productDisplayName
# 0               Turtle Check Men Navy Blue Shirt
# 1             Peter England Men Party Blue Jeans
# 2                       Titan Women Silver Watch
# 3  Manchester United Men Solid Black Track Pants
# 4                          Puma Men Grey T-shirt

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Adding a new column to dataset, with the file name
data['filename'] = data['id'].astype(str)+'.jpg'
data['filename'] = data['filename'].str.strip() 
data['filename'] = data['filename'].str.lower()  
data.head()
# Out:
#       id gender masterCategory subCategory  articleType  \
# 0  15970    Men        Apparel     Topwear       Shirts
# 1  39386    Men        Apparel  Bottomwear        Jeans
# 2  59263  Women    Accessories     Watches      Watches
# 3  21379    Men        Apparel  Bottomwear  Track Pants
# 4  53759    Men        Apparel     Topwear      Tshirts
#
#                               productDisplayName   filename
# 0               Turtle Check Men Navy Blue Shirt  15970.jpg
# 1             Peter England Men Party Blue Jeans  39386.jpg
# 2                       Titan Women Silver Watch  59263.jpg
# 3  Manchester United Men Solid Black Track Pants  21379.jpg
# 4                          Puma Men Grey T-shirt  53759.jpg

# %%
IMAGES_DIR = f'{DATASET_DIR}/images'

# %%
# Checking for invalid filenames and getting information about images
invalid_filenames = []
image_sizes = []
all_images = []
for filename in data['filename']:
    file_path = os.path.join(IMAGES_DIR, filename)
    if not os.path.exists(file_path):
        invalid_filenames.append(filename)
    else:
        img = Image.open(file_path)
        image_sizes.append(img.size)
print("Invalid filenames:\n")
for invalid in invalid_filenames:
    print(invalid)
# Out:
# Invalid filenames:
#
# 39403.jpg
# 39410.jpg
# 39401.jpg
# 39425.jpg
# 12347.jpg

# %%
# Checking for images which information might not be on the dataset 
all_images = set(os.listdir(IMAGES_DIR))
dataset_filenames = set(data['filename'])
orphaned_images = all_images-dataset_filenames
if orphaned_images:
    print("\nOrphaned images (not in the dataset):\n")
    for img in orphaned_images:
        print(img)
else:
    print("\nAll images in the directory have corresponding entries in the dataset.")
# Out:
# All images in the directory have corresponding entries in the dataset.

# %%
#There are some missing images, we will just erase their information from the dataset
data_cleaned = data[~data['filename'].isin(invalid_filenames)]
print(f'Total images that will be used as input: {len(data_cleaned)}')
# Out:
# Total images that will be used as input: 44441

# %%
#Load one of the images to check is dimensions
sample_image_filename = data.iloc[0].filename
sample_image_fullname = f'{IMAGES_DIR}/{sample_image_filename}'
sample_image_displayName =  data.iloc[0].productDisplayName
sample_image_articleType = data.iloc[0].articleType
img = load_img(sample_image_fullname)

print(f'Displaying image corresponding to the article \'{sample_image_displayName}\' of type \'{sample_image_articleType}\'')
img
# Out:
# Displaying image corresponding to the article 'Turtle Check Men Navy Blue Shirt' of type 'Shirts'
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80>

# %%
x=np.array(img)
x.shape
# Out:
# (80, 60, 3)

# %%
#Analyzing distribution of image dimensions
width, height = zip(*image_sizes)
plt.hist(width, bins=50, alpha=0.5, label='Width')
plt.hist(height, bins=50, alpha=0.5, label='Height')
plt.xlabel('Pixel Size')
plt.ylabel('Frequency')
plt.title('Distribution of Image Dimensions')
plt.legend()
plt.show()

# %%
# Conclusion: All the images have a size of 60x80

# %%
#Analyzing how many articles are there per class
sub_category_counts =data.groupby('articleType').size().reset_index(name='count')
sub_category_counts.sort_values(by='count', ascending=True)
# Out:
#              articleType  count
# 10   Body Wash and Scrub      1
# 26        Cushion Covers      1
# 54                  Ipad      1
# 46        Hair Accessory      1
# 106           Shoe Laces      1
# ..                   ...    ...
# 112         Sports Shoes   2036
# 140              Watches   2542
# 19          Casual Shoes   2846
# 104               Shirts   3217
# 134              Tshirts   7070
#
# [143 rows x 2 columns]

# %%
# Conclusion: There are some categories for which we have very few samples

# %%
# Filter the article types to keep only those with more than 4 samples 
#(we need at least 1 sample in each dataframe: train, val and test and with a small quantity of samples, it is difficult to achieve)
valid_article_types = sub_category_counts[sub_category_counts['count'] >= 4]['articleType']
data_cleaned = data_cleaned[data_cleaned['articleType'].isin(valid_article_types)]

# %%
count_classes_in_dataframe = data_cleaned['articleType'].nunique()
count_classes_in_dataframe
# Out:
# 128

# %%
#split the data into training, validation and test datasets
full_train_df, test_df = train_test_split(data_cleaned, test_size=0.2, random_state=42, stratify=data_cleaned['articleType'])
train_df, val_df = train_test_split(full_train_df, test_size=0.25, random_state=42, stratify=full_train_df['articleType'])

# %%
# Summary of the splits
print("Training Data Shape:", train_df.shape)
print("Validation Data Shape:", val_df.shape)
print("Test Data Shape:", test_df.shape)
# Out:
# Training Data Shape: (26649, 7)
# Validation Data Shape: (8883, 7)
# Test Data Shape: (8883, 7)

# %%
print("Unique classes in training dataset:")
print(train_df['articleType'].value_counts())

print("\nUnique classes in validation dataset:")
print(val_df['articleType'].value_counts())

print("\nUnique classes in test dataset:")
print(test_df['articleType'].value_counts())
# Out:
# Unique classes in training dataset:
# articleType
# Tshirts             4241
# Shirts              1929
# Casual Shoes        1708
# Watches             1525
# Sports Shoes        1222
#                     ...
# Beauty Accessory       2
# Makeup Remover         2
# Lip Plumper            2
# Robe                   2
# Lehenga Choli          2
# Name: count, Length: 128, dtype: int64
#
# Unique classes in validation dataset:
# articleType
# Tshirts            1414
# Shirts              643
# Casual Shoes        569
# Watches             508
# Sports Shoes        407
#                    ...
# Lehenga Choli         1
# Eye Cream             1
# Nail Essentials       1
# Umbrellas             1
# Nehru Jackets         1
# Name: count, Length: 128, dtype: int64
#
# Unique classes in test dataset:
# articleType
# Tshirts             1414
# Shirts               643
# Casual Shoes         569
# Watches              509
# Sports Shoes         407
#                     ...
# Wristbands             1
# Headband               1
# Lehenga Choli          1
# Beauty Accessory       1
# Toner                  1
# Name: count, Length: 128, dtype: int64

# %% [markdown]
# # Transfering learning

# %% [markdown]
# ## Preparing input for Model v1 with MobileNetV2

# %%
# defining a target size for images
TARGET_SIZE = (96, 96)
#defining a batch size
BATCH_SIZE=32
#defining a max queue size (count of batches preloaded in the queue while the model is training)
MAX_QUEUE_SIZE=10

# %%
# calculating how many workers threads for loading data
##warning: it is not certain that these parameters are being used by the ImageDataGenerator
num_cores = os.cpu_count()
workers = int(num_cores / 2)
use_multiprocessing=False
if workers>1:
   use_multiprocessing=True

# %%
#Read images by using ImageDataGenerator (we will use the articleType as our class)
train_image_gen = ImageDataGenerator(preprocessing_function=mobile_preprocess_input)
train_gen = train_image_gen.flow_from_dataframe(
    dataframe=train_df,
    directory=IMAGES_DIR, 
    x_col='filename',  
    y_col='articleType', 
    target_size=TARGET_SIZE, 
    batch_size=BATCH_SIZE,
    class_mode='categorical',  
    workers = workers,
    use_multiprocessing=use_multiprocessing,
    max_queue_size=MAX_QUEUE_SIZE
)
# Out:
# Found 26649 validated image filenames belonging to 128 classes.

# %%
val_image_gen = ImageDataGenerator(preprocessing_function=mobile_preprocess_input)
val_gen = val_image_gen.flow_from_dataframe(
    dataframe=val_df,
    directory=IMAGES_DIR, 
    x_col='filename',  
    y_col='articleType', 
    target_size=TARGET_SIZE, 
    batch_size=BATCH_SIZE,
    class_mode='categorical',  
    shuffle=False,
    workers = workers,
    use_multiprocessing=use_multiprocessing,
    max_queue_size=MAX_QUEUE_SIZE    
)
# Out:
# Found 8883 validated image filenames belonging to 128 classes.

# %%
generated_classes = list(train_gen.class_indices.keys())
classes_in_dataframe = list(train_gen.class_indices.keys())
if set(classes_in_dataframe) == set(generated_classes):
    print("\nThe classes in train_df match the classes in the ImageDataGenerator.")
else:
    print("\nThere is a mismatch between the classes!")
    print("Classes in train_df:", classes_in_dataframe)
    print("Classes from ImageDataGenerator:", generated_classes)
# Out:
# The classes in train_df match the classes in the ImageDataGenerator.

# %%
class_indices = train_gen.class_indices
class_indices
# Out:
# {'Accessory Gift Set': 0,
#  'Baby Dolls': 1,
#  'Backpacks': 2,
#  'Bangle': 3,
#  'Basketballs': 4,
#  'Bath Robe': 5,
#  'Beauty Accessory': 6,
#  'Belts': 7,
#  'Blazers': 8,
#  'Body Lotion': 9,
#  'Booties': 10,
#  'Boxers': 11,
#  'Bra': 12,
#  'Bracelet': 13,
#  'Briefs': 14,
#  'Camisoles': 15,
#  'Capris': 16,
#  'Caps': 17,
#  'Casual Shoes': 18,
#  'Churidar': 19,
#  'Clothing Set': 20,
#  'Clutches': 21,
#  'Compact': 22,
#  'Concealer': 23,
#  'Cufflinks': 24,
#  'Deodorant': 25,
#  'Dresses': 26,
#  'Duffel Bag': 27,
#  'Dupatta': 28,
#  'Earrings': 29,
#  'Eye Cream': 30,
#  'Eyeshadow': 31,
#  'Face Moisturisers': 32,
#  'Face Scrub and Exfoliator': 33,
#  'Face Wash and Cleanser': 34,
#  'Flats': 35,
#  'Flip Flops': 36,
#  'Footballs': 37,
#  'Formal Shoes': 38,
#  'Foundation and Primer': 39,
#  'Fragrance Gift Set': 40,
#  'Free Gifts': 41,
#  'Gloves': 42,
#  'Hair Colour': 43,
#  'Handbags': 44,
#  'Headband': 45,
#  'Heels': 46,
#  'Highlighter and Blush': 47,
#  'Innerwear Vests': 48,
#  'Jackets': 49,
#  'Jeans': 50,
#  'Jeggings': 51,
#  'Jewellery Set': 52,
#  'Jumpsuit': 53,
#  'Kajal and Eyeliner': 54,
#  'Kurta Sets': 55,
#  'Kurtas': 56,
#  'Kurtis': 57,
#  'Laptop Bag': 58,
#  'Leggings': 59,
#  'Lehenga Choli': 60,
#  'Lip Care': 61,
#  'Lip Gloss': 62,
#  'Lip Liner': 63,
#  'Lip Plumper': 64,
#  'Lipstick': 65,
#  'Lounge Pants': 66,
#  'Lounge Shorts': 67,
#  'Makeup Remover': 68,
#  'Mascara': 69,
#  'Mask and Peel': 70,
#  'Messenger Bag': 71,
#  'Mobile Pouch': 72,
#  'Mufflers': 73,
#  'Nail Essentials': 74,
#  'Nail Polish': 75,
#  'Necklace and Chains': 76,
#  'Nehru Jackets': 77,
#  'Night suits': 78,
#  'Nightdress': 79,
#  'Patiala': 80,
#  'Pendant': 81,
#  'Perfume and Body Mist': 82,
#  'Rain Jacket': 83,
#  'Ring': 84,
#  'Robe': 85,
#  'Rompers': 86,
#  'Rucksacks': 87,
#  'Salwar': 88,
#  'Salwar and Dupatta': 89,
#  'Sandals': 90,
#  'Sarees': 91,
#  'Scarves': 92,
#  'Shapewear': 93,
#  'Shirts': 94,
#  'Shoe Accessories': 95,
#  'Shorts': 96,
#  'Shrug': 97,
#  'Skirts': 98,
#  'Socks': 99,
#  'Sports Sandals': 100,
#  'Sports Shoes': 101,
#  'Stockings': 102,
#  'Stoles': 103,
#  'Sunglasses': 104,
#  'Sunscreen': 105,
#  'Suspenders': 106,
#  'Sweaters': 107,
#  'Sweatshirts': 108,
#  'Swimwear': 109,
#  'Ties': 110,
#  'Tights': 111,
#  'Toner': 112,
#  'Tops': 113,
#  'Track Pants': 114,
#  'Tracksuits': 115,
#  'Travel Accessory': 116,
#  'Trousers': 117,
#  'Trunk': 118,
#  'Tshirts': 119,
#  'Tunics': 120,
#  'Umbrellas': 121,
#  'Waist Pouch': 122,
#  'Waistcoat': 123,
#  'Wallets': 124,
#  'Watches': 125,
#  'Water Bottle': 126,
#  'Wristbands': 127}

# %%
count_classes = len(class_indices)
print (f'Category count:  {count_classes}')
# Out:
# Category count:  128

# %%
#Checking size of images and batches

train_batch_images_train, train_batch_labels = next(train_gen)  
if train_batch_labels.shape[1] == count_classes_in_dataframe:
    print("Training labels match the expected number of classes: OK")
else:
    print(f"Error: Training labels do not match the expected number of classes! Expected {count_classes_in_dataframe}, got {train_batch_labels.shape[1]}.")
print("Batch shape for training:", train_batch_images_train.shape) 


val_batch_images, val_batch_labels = next(val_gen)  
if val_batch_labels.shape[1] == count_classes_in_dataframe:
    print("Validation labels match the expected number of classes: OK")
else:
    print(f"Error: Validation labels do not match the expected number of classes! Expected {count_classes_in_dataframe}, got {val_batch_labels.shape[1]}.")
print("Batch shape for validation:", val_batch_images.shape)
# Out:
# Training labels match the expected number of classes: OK
# Batch shape for training: (32, 96, 96, 3)
# Validation labels match the expected number of classes: OK
# Batch shape for validation: (32, 96, 96, 3)

# %%
# Initialize a dictionary to store results for each model
model_results = {}

# %% [markdown]
# ## Create Model v1 with MobileNetV2

# %%
def make_model_Mobile_v1(learning_rate=0.01):
    #clear any unused session
    tf.keras.backend.clear_session()

    #creating a base model
    input_shape = (TARGET_SIZE[0], TARGET_SIZE[1], 3)
    base_model =MobileNetV2(weights='imagenet', input_shape=input_shape, include_top=False)
    # create a model from the base model
    base_model.trainable=False
    inputs = keras.Input(shape=input_shape)
    base = base_model(inputs, training=False)
    
    #pooling layer
    pooling = keras.layers.GlobalAveragePooling2D()
    vectors = pooling(base)
    
    #dense layer
    outputs = keras.layers.Dense(count_classes, activation='softmax')(vectors)

    #final model
    model = keras.Model(inputs, outputs)

    #compile de model
    optimizer =keras.optimizers.Adam(learning_rate=learning_rate)
    loss=keras.losses.CategoricalCrossentropy(from_logits=False)
    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    return model

# %%
model = make_model_Mobile_v1()
history=model.fit(train_gen, epochs=10, validation_data=val_gen)
# Out:
# I0000 00:00:1735514425.128460   15530 gpu_process_state.cc:201] Using CUDA malloc Async allocator for GPU: 0
# I0000 00:00:1735514425.132542   15530 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2245 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735514430.878637   15635 service.cc:148] XLA service 0x7f35b8001820 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1735514430.878686   15635 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650 Ti, Compute Capability 7.5
# 2024-12-29 18:20:30.967627: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1735514431.430300   15635 cuda_dnn.cc:529] Loaded cuDNN version 90600
#  12/833 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.2968 - loss: 5.0276
# I0000 00:00:1735514434.511896   15635 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 30s 28ms/step - accuracy: 0.6673 - loss: 2.4851 - val_accuracy: 0.7544 - val_loss: 2.1165
# Epoch 2/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.8137 - loss: 1.2700 - val_accuracy: 0.7761 - val_loss: 2.2099
# Epoch 3/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.8502 - loss: 1.0521 - val_accuracy: 0.7810 - val_loss: 2.4770
# Epoch 4/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.8738 - loss: 0.8627 - val_accuracy: 0.7977 - val_loss: 2.6275
# Epoch 5/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.8848 - loss: 0.7810 - val_accuracy: 0.7905 - val_loss: 3.0652
# Epoch 6/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 33s 40ms/step - accuracy: 0.8984 - loss: 0.6921 - val_accuracy: 0.7934 - val_loss: 3.0898
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - accuracy: 0.9030 - loss: 0.6619 - val_accuracy: 0.7674 - val_loss: 3.6354
# Epoch 8/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 28ms/step - accuracy: 0.9073 - loss: 0.6561 - val_accuracy: 0.7776 - val_loss: 3.7491
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9161 - loss: 0.6138 - val_accuracy: 0.7887 - val_loss: 3.8391
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.9167 - loss: 0.5873 - val_accuracy: 0.7861 - val_loss: 4.0389

# %%
#Plotting train and validation accuracy
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.xticks(np.arange(10), np.arange(1,11))
plt.legend()

# %%
## Conclusion: the model overfits the training data. Accuracy for validation dataset does not surpasses 80%

# %% [markdown]
# ## Create Model v1 with InceptionV3

# %% [markdown]
# ## Preparing input for Model v1 with InceptionV3

# %%
#Read images by using ImageDataGenerator (we will use the articleType as our class)
train_image_gen = ImageDataGenerator(preprocessing_function=inception_preprocess_input)
train_gen = train_image_gen.flow_from_dataframe(
    dataframe=train_df,
    directory=IMAGES_DIR, 
    x_col='filename',  
    y_col='articleType', 
    target_size=TARGET_SIZE, 
    batch_size=BATCH_SIZE,
    class_mode='categorical',  
    workers = workers,
    use_multiprocessing=use_multiprocessing,
    max_queue_size=MAX_QUEUE_SIZE
)
# Out:
# Found 26649 validated image filenames belonging to 128 classes.

# %%
val_image_gen = ImageDataGenerator(preprocessing_function=inception_preprocess_input)
val_gen = val_image_gen.flow_from_dataframe(
    dataframe=val_df,
    directory=IMAGES_DIR, 
    x_col='filename',  
    y_col='articleType', 
    target_size=TARGET_SIZE, 
    batch_size=BATCH_SIZE,
    class_mode='categorical',  
    shuffle=False,
    workers = workers,
    use_multiprocessing=use_multiprocessing,
    max_queue_size=MAX_QUEUE_SIZE    
)
# Out:
# Found 8883 validated image filenames belonging to 128 classes.

# %%
def make_model_Inception_v1(learning_rate=0.01):
    #clear any unused session
    tf.keras.backend.clear_session()

    #creating a base model
    input_shape = (TARGET_SIZE[0], TARGET_SIZE[1], 3)
    base_model =InceptionV3(weights='imagenet', input_shape=input_shape, include_top=False)
    # create a model from the base model
    base_model.trainable=False
    inputs = keras.Input(shape=input_shape)
    base = base_model(inputs, training=False)
    
    #pooling layer
    pooling = keras.layers.GlobalAveragePooling2D()
    vectors = pooling(base)
    
    #dense layer
    outputs = keras.layers.Dense(count_classes, activation='softmax')(vectors)

    #final model
    model = keras.Model(inputs, outputs)

    #compile de model
    optimizer =keras.optimizers.Adam(learning_rate=learning_rate)
    loss=keras.losses.CategoricalCrossentropy(from_logits=False)
    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    return model

# %%
model = make_model_Inception_v1()
history=model.fit(train_gen, epochs=10, validation_data=val_gen)
# Out:
# Epoch 1/10
# 832/833 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5299 - loss: 5.2122
# 2024-12-29 18:38:24.209573: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng34{k2=0,k4=1,k5=1,k6=0,k7=0,k19=0} for conv (f32[19,80,22,22]{3,2,1,0}, u8[0]{0}) custom-call(f32[19,64,22,22]{3,2,1,0}, f32[80,64,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2024-12-29 18:38:24.212966: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.209316841s
# Trying algorithm eng34{k2=0,k4=1,k5=1,k6=0,k7=0,k19=0} for conv (f32[19,80,22,22]{3,2,1,0}, u8[0]{0}) custom-call(f32[19,64,22,22]{3,2,1,0}, f32[80,64,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 53s 52ms/step - accuracy: 0.5300 - loss: 5.2117 - val_accuracy: 0.6601 - val_loss: 4.9024
# Epoch 2/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - accuracy: 0.7068 - loss: 3.2677 - val_accuracy: 0.6999 - val_loss: 4.6466
# Epoch 3/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 26s 31ms/step - accuracy: 0.7457 - loss: 2.6698 - val_accuracy: 0.6965 - val_loss: 6.2728
# Epoch 4/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 39s 47ms/step - accuracy: 0.7709 - loss: 2.4416 - val_accuracy: 0.7082 - val_loss: 5.4588
# Epoch 5/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 38s 46ms/step - accuracy: 0.7962 - loss: 2.1115 - val_accuracy: 0.6863 - val_loss: 6.4660
# Epoch 6/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 33s 40ms/step - accuracy: 0.8155 - loss: 1.9485 - val_accuracy: 0.6895 - val_loss: 6.6172
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 33s 39ms/step - accuracy: 0.8212 - loss: 1.8229 - val_accuracy: 0.6936 - val_loss: 6.8583
# Epoch 8/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 32s 39ms/step - accuracy: 0.8329 - loss: 1.7233 - val_accuracy: 0.6796 - val_loss: 7.2110
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 34s 41ms/step - accuracy: 0.8411 - loss: 1.6069 - val_accuracy: 0.6997 - val_loss: 7.3117
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 32s 38ms/step - accuracy: 0.8571 - loss: 1.4288 - val_accuracy: 0.7010 - val_loss: 7.8921

# %%
#Plotting train and validation accuracy
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.xticks(np.arange(10), np.arange(1,11))
plt.legend()

# %%
#Conclusion: the Mobile model performs better than the Inception model, and the latter one is slower
## so, the base layer of the model used in this project will be based on MobileNetV2

# %% [markdown]
# ### Adjusting learning rate for Model version 1

# %%
scores={}
print("Training with different learning rates:\n")
for lr in [0.0001, 0.001, 0.005, 0.01, 0.1]:
    print(lr)
    model = make_model_Mobile_v1(learning_rate=lr)
    history = model.fit(train_gen, epochs=10, validation_data=val_gen)
    scores[lr]= history.history

    print()
    print()
# Out:
# Training with different learning rates:
#
# 0.0001
# Epoch 1/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 28s 26ms/step - accuracy: 0.3733 - loss: 2.8116 - val_accuracy: 0.7083 - val_loss: 1.0936
# Epoch 2/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.7308 - loss: 0.9613 - val_accuracy: 0.7589 - val_loss: 0.8302
# Epoch 3/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.7830 - loss: 0.7378 - val_accuracy: 0.7844 - val_loss: 0.7220
# Epoch 4/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.8155 - loss: 0.6135 - val_accuracy: 0.7964 - val_loss: 0.6666
# Epoch 5/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 24s 29ms/step - accuracy: 0.8312 - loss: 0.5455 - val_accuracy: 0.8072 - val_loss: 0.6268
# Epoch 6/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.8474 - loss: 0.4940 - val_accuracy: 0.8118 - val_loss: 0.6028
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8591 - loss: 0.4518 - val_accuracy: 0.8153 - val_loss: 0.5852
# Epoch 8/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.8678 - loss: 0.4229 - val_accuracy: 0.8219 - val_loss: 0.5692
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8784 - loss: 0.3971 - val_accuracy: 0.8279 - val_loss: 0.5580
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.8879 - loss: 0.3622 - val_accuracy: 0.8282 - val_loss: 0.5481
#
#
# 0.001
# Epoch 1/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.6540 - loss: 1.3800 - val_accuracy: 0.8093 - val_loss: 0.6166
# Epoch 2/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.8509 - loss: 0.4493 - val_accuracy: 0.8209 - val_loss: 0.5749
# Epoch 3/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - accuracy: 0.8906 - loss: 0.3268 - val_accuracy: 0.8173 - val_loss: 0.6003
# Epoch 4/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9099 - loss: 0.2659 - val_accuracy: 0.8306 - val_loss: 0.5782
# Epoch 5/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9198 - loss: 0.2333 - val_accuracy: 0.8291 - val_loss: 0.5976
# Epoch 6/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9331 - loss: 0.1974 - val_accuracy: 0.8338 - val_loss: 0.5945
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9385 - loss: 0.1819 - val_accuracy: 0.8361 - val_loss: 0.6010
# Epoch 8/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9466 - loss: 0.1619 - val_accuracy: 0.8291 - val_loss: 0.6404
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9517 - loss: 0.1439 - val_accuracy: 0.8292 - val_loss: 0.6525
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9559 - loss: 0.1357 - val_accuracy: 0.8336 - val_loss: 0.6534
#
#
# 0.005
# Epoch 1/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.6840 - loss: 1.6011 - val_accuracy: 0.7832 - val_loss: 1.1986
# Epoch 2/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8324 - loss: 0.6923 - val_accuracy: 0.7922 - val_loss: 1.2639
# Epoch 3/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8634 - loss: 0.5429 - val_accuracy: 0.7969 - val_loss: 1.2677
# Epoch 4/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.8845 - loss: 0.4419 - val_accuracy: 0.8014 - val_loss: 1.4076
# Epoch 5/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9019 - loss: 0.3735 - val_accuracy: 0.8028 - val_loss: 1.4463
# Epoch 6/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.9060 - loss: 0.3514 - val_accuracy: 0.7930 - val_loss: 1.5638
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9141 - loss: 0.3234 - val_accuracy: 0.8162 - val_loss: 1.5133
# Epoch 8/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9244 - loss: 0.3022 - val_accuracy: 0.7890 - val_loss: 1.7456
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9259 - loss: 0.2868 - val_accuracy: 0.8041 - val_loss: 1.9827
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9267 - loss: 0.2898 - val_accuracy: 0.8058 - val_loss: 1.9783
#
#
# 0.01
# Epoch 1/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.6575 - loss: 2.5462 - val_accuracy: 0.7751 - val_loss: 2.2747
# Epoch 2/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8150 - loss: 1.3108 - val_accuracy: 0.7738 - val_loss: 2.3265
# Epoch 3/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.8548 - loss: 1.0293 - val_accuracy: 0.7801 - val_loss: 2.5374
# Epoch 4/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8676 - loss: 0.9304 - val_accuracy: 0.7938 - val_loss: 2.6791
# Epoch 5/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.8826 - loss: 0.8054 - val_accuracy: 0.7898 - val_loss: 2.8612
# Epoch 6/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.8909 - loss: 0.7363 - val_accuracy: 0.7813 - val_loss: 3.4458
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.8981 - loss: 0.7197 - val_accuracy: 0.8023 - val_loss: 3.1373
# Epoch 8/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9141 - loss: 0.6104 - val_accuracy: 0.7906 - val_loss: 3.5053
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9193 - loss: 0.5584 - val_accuracy: 0.7939 - val_loss: 3.6051
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9206 - loss: 0.5719 - val_accuracy: 0.7975 - val_loss: 3.9448
#
#
# 0.1
# Epoch 1/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.6390 - loss: 24.2160 - val_accuracy: 0.7531 - val_loss: 22.5187
# Epoch 2/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.7971 - loss: 14.7083 - val_accuracy: 0.7781 - val_loss: 24.5267
# Epoch 3/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.8328 - loss: 11.3559 - val_accuracy: 0.7812 - val_loss: 25.6491
# Epoch 4/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.8591 - loss: 10.0244 - val_accuracy: 0.7830 - val_loss: 28.6373
# Epoch 5/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.8708 - loss: 9.2196 - val_accuracy: 0.7885 - val_loss: 29.2649
# Epoch 6/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.8867 - loss: 7.7415 - val_accuracy: 0.7779 - val_loss: 34.0485
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.8902 - loss: 7.6882 - val_accuracy: 0.7993 - val_loss: 32.5628
# Epoch 8/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9033 - loss: 6.8497 - val_accuracy: 0.8019 - val_loss: 33.1354
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.9064 - loss: 6.6702 - val_accuracy: 0.7681 - val_loss: 38.4391
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9081 - loss: 6.3656 - val_accuracy: 0.7955 - val_loss: 37.2779

# %%
#Plotting the train accuracy
for lr, hist in scores.items():
    plt.plot(hist['accuracy'], label=lr)

plt.title('Training Accuracy for Selected Learning Rates')
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')

plt.xticks(np.arange(10), np.arange(1,11))
plt.legend()

# %%
#Plotting the validation accuracy
for lr, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=lr)

    
plt.title('Validation Accuracy for Selected Learning Rates')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

plt.xticks(np.arange(10), np.arange(1,11))
plt.legend()

# %%
#Plotting validation and train accuracy only for learning rate 0.001
lr=0.001
hist = scores[lr]
plt.figure(figsize=(10, 5))
plt.plot(hist['accuracy'], label=f'Training Accuracy (LR: {lr})')
plt.plot(hist['val_accuracy'], label=f'Validation Accuracy (LR: {lr})')

plt.title('Accuracy for Selected Learning Rates')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

plt.xticks(np.arange(len(hist['val_accuracy'])), np.arange(1, len(hist['val_accuracy']) + 1))
plt.legend()
plt.grid()
plt.show()

# %%
#Plotting validation and train accuracy only for learning rate 0.0001
lr=0.0001
hist = scores[lr]
plt.figure(figsize=(10, 5))
plt.plot(hist['accuracy'], label=f'Training Accuracy (LR: {lr})')
plt.plot(hist['val_accuracy'], label=f'Validation Accuracy (LR: {lr})')

plt.title('Accuracy for Selected Learning Rates')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

plt.xticks(np.arange(len(hist['val_accuracy'])), np.arange(1, len(hist['val_accuracy']) + 1))
plt.legend()
plt.grid()
plt.show()

# %%
#Conclusion: The model takes longer to learn with a rate of 0.0001, # but the validation and training accuracies are closer together 
#Besides that, does not overfit and after 5 epochs we already have 80% accuracy or better
best_learning_rate=0.0001

# %%
MODELS_DIR = '../models'

# %%
#Defining function to delete any previously saved files
def delete_previous_checkpoint_files(filename_pattern):
    # Compile the regex pattern
    regex = re.compile(filename_pattern)
    
    # List all files in the specified directory
    files = os.listdir(MODELS_DIR)

    # Filter files matching the regex pattern
    matching_files = [f for f in files if regex.match(f)]
    
    # Check if there are matching files
    if not matching_files:
        print("No matching files found for deletion.")
        return 

    # Iterate through the matching files and delete them
    for checkpoint_file in matching_files:
        full_file_path = os.path.join(MODELS_DIR, checkpoint_file)
        try:
            os.remove(full_file_path)  # Attempt to delete the file
            print(f"Deleted checkpoint file: {checkpoint_file}")
        except Exception as e:
            print(f"Error deleting file {full_file_path}: {e}")

# %%
#Define class for a custom checkpoint
class CustomModelCheckpoint(ModelCheckpoint):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.best_accuracy = 0.0
        self.best_model_file = ""

    def on_epoch_end(self, epoch, logs=None):
        super().on_epoch_end(epoch, logs)  # Call the parent method
        current_val_accuracy = logs.get('val_accuracy')

        if current_val_accuracy > self.best_accuracy:
            # Update best values
            self.best_accuracy = current_val_accuracy
            self.best_model_file = self.filepath.format(epoch=epoch+1, **logs)
            print(f"New best model saved at epoch {epoch+1} with validation accuracy {self.best_accuracy:.3f}.Filename:{self.best_model_file}")

# %%
#deleting any previous files
print('Deleting files previously saved to output directory\n')
delete_previous_checkpoint_files(r'Mobile_v1.*\.keras')
print(f'\nTraining the model with learning rate {best_learning_rate}\n')
#definining a checkpoint to save the model when the accuracy is the max accuracy
custom_checkpoint = CustomModelCheckpoint(f'{MODELS_DIR}/Mobile_v1_{{epoch:02d}}_{{val_accuracy:.3f}}.keras',
                                save_best_only=True,
                                monitor='val_accuracy',
                                mode='max')

model = make_model_Mobile_v1(learning_rate=best_learning_rate)
history = model.fit(
    train_gen,
    epochs=10,
    validation_data=val_gen,
    callbacks = [custom_checkpoint]
)
# Out:
# Deleting files previously saved to output directory
#
# Deleted checkpoint file: Mobile_v1_09_0.823.keras
# Deleted checkpoint file: Mobile_v1_10_0.827.keras
# Deleted checkpoint file: Mobile_v1_03_0.781.keras
# Deleted checkpoint file: Mobile_v1_06_0.811.keras
# Deleted checkpoint file: Mobile_v1_05_0.806.keras
# Deleted checkpoint file: Mobile_v1_07_0.819.keras
# Deleted checkpoint file: Mobile_v1_08_0.823.keras
# Deleted checkpoint file: Mobile_v1_02_0.759.keras
# Deleted checkpoint file: Mobile_v1_04_0.797.keras
# Deleted checkpoint file: Mobile_v1_01_0.707.keras
#
# Training the model with learning rate 0.0001
#
# Epoch 1/10
# New best model saved at epoch 1 with validation accuracy 0.712.Filename:../models/Mobile_v1_01_0.712.keras414
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 28s 28ms/step - accuracy: 0.3547 - loss: 2.8380 - val_accuracy: 0.7118 - val_loss: 1.0766
# Epoch 2/10
# New best model saved at epoch 2 with validation accuracy 0.757.Filename:../models/Mobile_v1_02_0.757.keras692
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.7278 - loss: 0.9689 - val_accuracy: 0.7574 - val_loss: 0.8220
# Epoch 3/10
# New best model saved at epoch 3 with validation accuracy 0.783.Filename:../models/Mobile_v1_03_0.783.keras411
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.7766 - loss: 0.7410 - val_accuracy: 0.7834 - val_loss: 0.7239
# Epoch 4/10
# New best model saved at epoch 4 with validation accuracy 0.796.Filename:../models/Mobile_v1_04_0.796.keras238
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8098 - loss: 0.6238 - val_accuracy: 0.7961 - val_loss: 0.6650
# Epoch 5/10
# New best model saved at epoch 5 with validation accuracy 0.802.Filename:../models/Mobile_v1_05_0.802.keras460
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.8330 - loss: 0.5460 - val_accuracy: 0.8024 - val_loss: 0.6324
# Epoch 6/10
# New best model saved at epoch 6 with validation accuracy 0.815.Filename:../models/Mobile_v1_06_0.815.keras001
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.8439 - loss: 0.5001 - val_accuracy: 0.8148 - val_loss: 0.6037
# Epoch 7/10
# New best model saved at epoch 7 with validation accuracy 0.819.Filename:../models/Mobile_v1_07_0.819.keras558
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.8592 - loss: 0.4558 - val_accuracy: 0.8189 - val_loss: 0.5871
# Epoch 8/10
# New best model saved at epoch 8 with validation accuracy 0.824.Filename:../models/Mobile_v1_08_0.824.keras247
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.8655 - loss: 0.4247 - val_accuracy: 0.8239 - val_loss: 0.5701
# Epoch 9/10
# New best model saved at epoch 9 with validation accuracy 0.826.Filename:../models/Mobile_v1_09_0.826.keras939
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8763 - loss: 0.3939 - val_accuracy: 0.8264 - val_loss: 0.5593
# Epoch 10/10
# New best model saved at epoch 10 with validation accuracy 0.828.Filename:../models/Mobile_v1_10_0.828.keras34
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.8829 - loss: 0.3734 - val_accuracy: 0.8280 - val_loss: 0.5502

# %%
plt.figure(figsize=(10, 5))
plt.plot(hist['accuracy'], label=f'Training Accuracy)')
plt.plot(hist['val_accuracy'], label=f'Validation Accuracy)')

plt.title('Accuracy for Model version 1')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

plt.xticks(np.arange(len(hist['val_accuracy'])), np.arange(1, len(hist['val_accuracy']) + 1))
plt.legend()
plt.grid()
plt.show()

# %%
print(f"Best Validation Accuracy for 'Mobile version 1' model: {round(custom_checkpoint.best_accuracy, 4)}")
print(f"Saved Model File: {custom_checkpoint.best_model_file}")
# Out:
# Best Validation Accuracy for 'Mobile version 1' model: 0.828
# Saved Model File: ../models/Mobile_v1_10_0.828.keras

# %%
#Even when the best accuracy is achieved later in the training, I will select the model at epoch 4, because there is a smaller
#gap between the training accuracy and the validation accuracy and the validation accuracy is not bad, it is over 80%

#build checkpoint file name for epoch 5
epoch=5
epoch_index = epoch-1  #the epochs are 0 indexed
val_accuracy = history.history['val_accuracy'][epoch_index]  
checkpoint_filename = f'Mobile_v1_{epoch:02d}_{val_accuracy:.3f}.keras'

#verify that the file exists
checkpoint_file_path = os.path.join(MODELS_DIR, checkpoint_filename)

# Check if the file exists
if not os.path.isfile(checkpoint_file_path):
    print(f"Checkpoint file does not exist: {checkpoint_file_path}")
    checkpoint_filename='not found'

#store results for model version 1
model_results['mobile_v1'] = {
    'accuracy': round(val_accuracy, 4),
    'filename': checkpoint_filename
}

# %%
model_results['mobile_v1']
# Out:
# {'accuracy': 0.8024, 'filename': 'Mobile_v1_05_0.802.keras'}

# %% [markdown]
# ## Create Model version 2 by adding another inner layer

# %%
def make_model_Mobile_v2(learning_rate=0.01, inner_layer_units=1420):
    #clear any unused session
    tf.keras.backend.clear_session()

    #creating a base model
    input_shape = (TARGET_SIZE[0], TARGET_SIZE[1], 3)
    base_model =MobileNetV2(weights='imagenet', input_shape=input_shape, include_top=False)
    # create a model from the base model
    base_model.trainable=False
    inputs = keras.Input(shape=input_shape)
    base = base_model(inputs, training=False)
    
    #pooling layer
    pooling = keras.layers.GlobalAveragePooling2D()
    vectors = pooling(base)

    #dense layer 1
    inner = keras.layers.Dense(inner_layer_units, activation='relu')(vectors)
    
    #dense layer 2
    outputs = keras.layers.Dense(units=count_classes, activation='softmax')(inner)

    #final model
    model = keras.Model(inputs, outputs)

    #compile de model
    optimizer =keras.optimizers.Adam(learning_rate=learning_rate)
    loss=keras.losses.CategoricalCrossentropy(from_logits=False)
    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    return model

# %% [markdown]
# ### Find the best inner layer size

# %%
print('Deleting files previously saved to output directory\n')
delete_previous_checkpoint_files(r'Mobile_v2_size.*\.keras')
print(f'Training the model with different sizes for the inner layer \n')

scores={}
for size in [count_classes*3, count_classes*5, count_classes*10, count_classes*20]:
    print(f'Fitting model for size {size}')
    custom_checkpoint = CustomModelCheckpoint(f'{MODELS_DIR}/Mobile_v2_size{size}_{{epoch:02d}}_{{val_accuracy:.3f}}.keras',
                                save_best_only=False,
                                monitor='val_accuracy',
                                mode='max')    
    model = make_model_Mobile_v2(learning_rate=best_learning_rate, inner_layer_units=size)
    history = model.fit(train_gen, epochs=10, validation_data=val_gen, callbacks = [custom_checkpoint])
    scores[size] = history.history
    print()
    print()
# Out:
# Deleting files previously saved to output directory
#
# Deleted checkpoint file: Mobile_v2_size384_06_0.835.keras
# Deleted checkpoint file: Mobile_v2_size640_08_0.839.keras
# Deleted checkpoint file: Mobile_v2_size2560_02_0.827.keras
# Deleted checkpoint file: Mobile_v2_size640_01_0.784.keras
# Deleted checkpoint file: Mobile_v2_size2560_01_0.808.keras
# Deleted checkpoint file: Mobile_v2_size640_10_0.839.keras
# Deleted checkpoint file: Mobile_v2_size384_02_0.805.keras
# Deleted checkpoint file: Mobile_v2_size2560_05_0.834.keras
# Deleted checkpoint file: Mobile_v2_size384_04_0.827.keras
# Deleted checkpoint file: Mobile_v2_size640_03_0.822.keras
# Deleted checkpoint file: Mobile_v2_size384_05_0.828.keras
# Deleted checkpoint file: Mobile_v2_size384_07_0.835.keras
# Deleted checkpoint file: Mobile_v2_size1280_07_0.838.keras
# Deleted checkpoint file: Mobile_v2_size384_01_0.771.keras
# Deleted checkpoint file: Mobile_v2_size640_02_0.815.keras
# Deleted checkpoint file: Mobile_v2_size640_05_0.834.keras
# Deleted checkpoint file: Mobile_v2_size1280_01_0.796.keras
# Deleted checkpoint file: Mobile_v2_size384_09_0.835.keras
# Deleted checkpoint file: Mobile_v2_size384_03_0.816.keras
# Deleted checkpoint file: Mobile_v2_size1280_03_0.837.keras
# Deleted checkpoint file: Mobile_v2_size1280_02_0.818.keras
# Deleted checkpoint file: Mobile_v2_size640_06_0.835.keras
# Deleted checkpoint file: Mobile_v2_size2560_06_0.839.keras
# Deleted checkpoint file: Mobile_v2_size384_10_0.839.keras
# Deleted checkpoint file: Mobile_v2_size640_04_0.823.keras
# Deleted checkpoint file: Mobile_v2_size2560_07_0.842.keras
# Deleted checkpoint file: Mobile_v2_size2560_03_0.834.keras
# Training the model with different sizes for the inner layer
#
# Fitting model for size 384
# Epoch 1/10
# New best model saved at epoch 1 with validation accuracy 0.767.Filename:../models/Mobile_v2_size384_01_0.767.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 35s 36ms/step - accuracy: 0.5486 - loss: 2.0681 - val_accuracy: 0.7672 - val_loss: 0.8151
# Epoch 2/10
# New best model saved at epoch 2 with validation accuracy 0.803.Filename:../models/Mobile_v2_size384_02_0.803.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.7998 - loss: 0.7021 - val_accuracy: 0.8034 - val_loss: 0.6616
# Epoch 3/10
# New best model saved at epoch 3 with validation accuracy 0.813.Filename:../models/Mobile_v2_size384_03_0.813.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.8419 - loss: 0.5367 - val_accuracy: 0.8132 - val_loss: 0.6054
# Epoch 4/10
# New best model saved at epoch 4 with validation accuracy 0.820.Filename:../models/Mobile_v2_size384_04_0.820.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.8664 - loss: 0.4421 - val_accuracy: 0.8199 - val_loss: 0.5733
# Epoch 5/10
# New best model saved at epoch 5 with validation accuracy 0.826.Filename:../models/Mobile_v2_size384_05_0.826.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8849 - loss: 0.3802 - val_accuracy: 0.8262 - val_loss: 0.5584
# Epoch 6/10
# New best model saved at epoch 6 with validation accuracy 0.831.Filename:../models/Mobile_v2_size384_06_0.831.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.8980 - loss: 0.3288 - val_accuracy: 0.8315 - val_loss: 0.5358
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.9141 - loss: 0.2929 - val_accuracy: 0.8299 - val_loss: 0.5308
# Epoch 8/10
# New best model saved at epoch 8 with validation accuracy 0.833.Filename:../models/Mobile_v2_size384_08_0.833.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.9245 - loss: 0.2580 - val_accuracy: 0.8333 - val_loss: 0.5294
# Epoch 9/10
# New best model saved at epoch 9 with validation accuracy 0.836.Filename:../models/Mobile_v2_size384_09_0.836.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - accuracy: 0.9340 - loss: 0.2287 - val_accuracy: 0.8361 - val_loss: 0.5233
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9428 - loss: 0.2052 - val_accuracy: 0.8332 - val_loss: 0.5328
#
#
# Fitting model for size 640
# Epoch 1/10
# New best model saved at epoch 1 with validation accuracy 0.780.Filename:../models/Mobile_v2_size640_01_0.780.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 29s 29ms/step - accuracy: 0.5869 - loss: 1.8477 - val_accuracy: 0.7803 - val_loss: 0.7425
# Epoch 2/10
# New best model saved at epoch 2 with validation accuracy 0.809.Filename:../models/Mobile_v2_size640_02_0.809.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.8110 - loss: 0.6336 - val_accuracy: 0.8085 - val_loss: 0.6287
# Epoch 3/10
# New best model saved at epoch 3 with validation accuracy 0.820.Filename:../models/Mobile_v2_size640_03_0.820.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.8589 - loss: 0.4661 - val_accuracy: 0.8200 - val_loss: 0.5722
# Epoch 4/10
# New best model saved at epoch 4 with validation accuracy 0.826.Filename:../models/Mobile_v2_size640_04_0.826.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.8818 - loss: 0.3846 - val_accuracy: 0.8255 - val_loss: 0.5562
# Epoch 5/10
# New best model saved at epoch 5 with validation accuracy 0.829.Filename:../models/Mobile_v2_size640_05_0.829.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9027 - loss: 0.3201 - val_accuracy: 0.8293 - val_loss: 0.5360
# Epoch 6/10
# New best model saved at epoch 6 with validation accuracy 0.835.Filename:../models/Mobile_v2_size640_06_0.835.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9190 - loss: 0.2736 - val_accuracy: 0.8345 - val_loss: 0.5387
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9287 - loss: 0.2370 - val_accuracy: 0.8343 - val_loss: 0.5327
# Epoch 8/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.9388 - loss: 0.2101 - val_accuracy: 0.8318 - val_loss: 0.5293
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9487 - loss: 0.1807 - val_accuracy: 0.8297 - val_loss: 0.5406
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9577 - loss: 0.1559 - val_accuracy: 0.8335 - val_loss: 0.5436
#
#
# Fitting model for size 1280
# Epoch 1/10
# New best model saved at epoch 1 with validation accuracy 0.804.Filename:../models/Mobile_v2_size1280_01_0.804.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 28s 27ms/step - accuracy: 0.6276 - loss: 1.6214 - val_accuracy: 0.8045 - val_loss: 0.6754
# Epoch 2/10
# New best model saved at epoch 2 with validation accuracy 0.820.Filename:../models/Mobile_v2_size1280_02_0.820.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8364 - loss: 0.5432 - val_accuracy: 0.8201 - val_loss: 0.5810
# Epoch 3/10
# New best model saved at epoch 3 with validation accuracy 0.825.Filename:../models/Mobile_v2_size1280_03_0.825.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8789 - loss: 0.3945 - val_accuracy: 0.8247 - val_loss: 0.5494
# Epoch 4/10
# New best model saved at epoch 4 with validation accuracy 0.826.Filename:../models/Mobile_v2_size1280_04_0.826.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9039 - loss: 0.3085 - val_accuracy: 0.8258 - val_loss: 0.5470
# Epoch 5/10
# New best model saved at epoch 5 with validation accuracy 0.836.Filename:../models/Mobile_v2_size1280_05_0.836.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9272 - loss: 0.2448 - val_accuracy: 0.8361 - val_loss: 0.5206
# Epoch 6/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9437 - loss: 0.1974 - val_accuracy: 0.8343 - val_loss: 0.5361
# Epoch 7/10
# New best model saved at epoch 7 with validation accuracy 0.837.Filename:../models/Mobile_v2_size1280_07_0.837.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9513 - loss: 0.1686 - val_accuracy: 0.8368 - val_loss: 0.5365
# Epoch 8/10
# New best model saved at epoch 8 with validation accuracy 0.842.Filename:../models/Mobile_v2_size1280_08_0.842.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9630 - loss: 0.1399 - val_accuracy: 0.8423 - val_loss: 0.5350
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.9697 - loss: 0.1161 - val_accuracy: 0.8362 - val_loss: 0.5627
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9778 - loss: 0.0933 - val_accuracy: 0.8413 - val_loss: 0.5409
#
#
# Fitting model for size 2560
# Epoch 1/10
# New best model saved at epoch 1 with validation accuracy 0.808.Filename:../models/Mobile_v2_size2560_01_0.808.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 33s 29ms/step - accuracy: 0.6619 - loss: 1.4166 - val_accuracy: 0.8078 - val_loss: 0.6227
# Epoch 2/10
# New best model saved at epoch 2 with validation accuracy 0.830.Filename:../models/Mobile_v2_size2560_02_0.830.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.8560 - loss: 0.4707 - val_accuracy: 0.8302 - val_loss: 0.5515
# Epoch 3/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8933 - loss: 0.3395 - val_accuracy: 0.8289 - val_loss: 0.5428
# Epoch 4/10
# New best model saved at epoch 4 with validation accuracy 0.832.Filename:../models/Mobile_v2_size2560_04_0.832.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9262 - loss: 0.2476 - val_accuracy: 0.8322 - val_loss: 0.5397
# Epoch 5/10
# New best model saved at epoch 5 with validation accuracy 0.839.Filename:../models/Mobile_v2_size2560_05_0.839.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9419 - loss: 0.1946 - val_accuracy: 0.8387 - val_loss: 0.5281
# Epoch 6/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.9577 - loss: 0.1519 - val_accuracy: 0.8368 - val_loss: 0.5418
# Epoch 7/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9662 - loss: 0.1235 - val_accuracy: 0.8350 - val_loss: 0.5460
# Epoch 8/10
# New best model saved at epoch 8 with validation accuracy 0.843.Filename:../models/Mobile_v2_size2560_08_0.843.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.9774 - loss: 0.0936 - val_accuracy: 0.8430 - val_loss: 0.5547
# Epoch 9/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9841 - loss: 0.0744 - val_accuracy: 0.8394 - val_loss: 0.5855
# Epoch 10/10
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9866 - loss: 0.0599 - val_accuracy: 0.8325 - val_loss: 0.5982

# %%
#Plotting the results
for size, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=('val=%s' % size))

plt.title('Accuracy for Model version 2 with Different Sizes for Inner Layer')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

plt.xticks(np.arange(10), np.arange(1,11))
plt.yticks([0.80, 0.83, 0.835, 0.84, 0.845])
plt.legend()

# %%
#Plotting training and validation accuracy for model with inner lazyer of size 2560
size = 2560
hist = scores[size]
plt.plot(hist['accuracy'], label=('train=%s' % size))
plt.plot(hist['val_accuracy'], label=('val=%s' % size))

plt.title('Accuracy for Model version 2 with Inner Layer of Size 2560')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

plt.xticks(np.arange(10), np.arange(1,11))
plt.legend()

# %%
#Plotting training and validation accuracy for model with inner lazyer of size 1280
size = 1280
hist = scores[size]
plt.plot(hist['accuracy'], label=('train=%s' % size))
plt.plot(hist['val_accuracy'], label=('val=%s' % size))

plt.title('Accuracy for Model version 2 with Inner Layer of Size 1280')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

plt.xticks(np.arange(10), np.arange(1,11))
plt.legend()

# %%
##Conclusion, the model overfits, after the second epoch the gap between train accuracy and validation accuracy increases

# %%
#Building a resume with the results
best_models_info = {}

for size in scores.keys():
    best_val_accuracy = max(scores[size]['val_accuracy'])
    
    checkpoint_filename_pattern = f'Mobile_v2_size{size}_*_{best_val_accuracy:.3f}.keras'
    checkpoint_files = glob.glob(os.path.join(MODELS_DIR, checkpoint_filename_pattern))
    
    if checkpoint_files:
        best_models_info[size] = {
            'best_accuracy': best_val_accuracy,
            'checkpoint_file': checkpoint_files[0]  # Get the first matching file
        }
    else:
        print(f"No checkpoint files found for size {size} with accuracy {best_val_accuracy:.3f}")

for size, info in best_models_info.items():
    print(f"Best model for inner layer size {size}:")
    print(f"Best Validation Accuracy: {info['best_accuracy']:.3f}")
    print(f"Checkpoint file: {info['checkpoint_file']}")
# Out:
# Best model for inner layer size 384:
# Best Validation Accuracy: 0.836
# Checkpoint file: ../models/Mobile_v2_size384_09_0.836.keras
# Best model for inner layer size 640:
# Best Validation Accuracy: 0.835
# Checkpoint file: ../models/Mobile_v2_size640_06_0.835.keras
# Best model for inner layer size 1280:
# Best Validation Accuracy: 0.842
# Checkpoint file: ../models/Mobile_v2_size1280_08_0.842.keras
# Best model for inner layer size 2560:
# Best Validation Accuracy: 0.843
# Checkpoint file: ../models/Mobile_v2_size2560_08_0.843.keras

# %%
inner_layer_size_higher_accuracy = 2560
print(f"Best Validation Accuracy for 'Mobile version 2' model: {round(best_models_info[inner_layer_size_higher_accuracy]['best_accuracy'], 4)}")
print(f"Saved Model File: {best_models_info[inner_layer_size_higher_accuracy]['checkpoint_file']}")
# Out:
# Best Validation Accuracy for 'Mobile version 2' model: 0.843
# Saved Model File: ../models/Mobile_v2_size2560_08_0.843.keras

# %%
# Conclusion: The inner layer size of 2560 provides the best accuracy, but this occurs at an epoch when the model is already overfitting. 
# Therefore, if I were to keep an inner layer, I would choose a size of 1280 and use the model from the second epoch.
#build checkpoint file name for epoch 2
best_inner_layer_size=1280
epoch=2
epoch_index = epoch-1  #the epochs are 0 indexed
val_accuracy = scores[best_inner_layer_size]['val_accuracy'][epoch_index]  
checkpoint_filename = f'Mobile_v2_size1280_{epoch:02d}_{val_accuracy:.3f}.keras'

#verify that the file exists
checkpoint_file_path = os.path.join(MODELS_DIR, checkpoint_filename)

# Check if the file exists
if not os.path.isfile(checkpoint_file_path):
    print(f"Checkpoint file does not exist: {checkpoint_file_path}")
    checkpoint_filename='not found'

#store results for model version 1
model_results['mobile_v2'] = {
    'accuracy': round(val_accuracy, 4),
    'filename': checkpoint_filename
}

# %%
model_results['mobile_v2']
# Out:
# {'accuracy': 0.8201, 'filename': 'Mobile_v2_size1280_02_0.820.keras'}

# %% [markdown]
# ### Creating Mobile Model version 3 by adding a dropout layer

# %%
def make_model_Mobile_v3(learning_rate, inner_layer_units, droprate):
    
    #clear any unused session
    tf.keras.backend.clear_session()

    #creating a base model
    input_shape = (TARGET_SIZE[0], TARGET_SIZE[1], 3)
    base_model =MobileNetV2(weights='imagenet', input_shape=input_shape, include_top=False)
    # create a model from the base model
    base_model.trainable=False
    inputs = keras.Input(shape=input_shape)
    base = base_model(inputs, training=False)
    
    #pooling layer
    vectors = keras.layers.GlobalAveragePooling2D()(base)

    #dense layer 1
    inner = keras.layers.Dense(inner_layer_units, activation='relu')(vectors)

    #dropout for inner layer 1
    drop = keras.layers.Dropout(droprate)(inner)
    
    #dense layer 2
    outputs = keras.layers.Dense(units=count_classes, activation='softmax')(drop)

    #final model
    model = keras.Model(inputs, outputs)

    #compile de model
    optimizer =keras.optimizers.Adam(learning_rate=learning_rate)
    loss=keras.losses.CategoricalCrossentropy(from_logits=False)
    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    return model

# %%
print('Deleting files previously saved to output directory\n')
delete_previous_checkpoint_files(r'Mobile_v3_droprate.*\.keras')
print(f'Training the model with different dropout rates for the inner layer \n')

droprates = [0.0, 0.05, 0.1, 0.2]
scores={}
#I initially experimented with a variety of dropout rates during the training and 30 epochs
#but the accuracy wasnt higher and it took too long, so I narrowed it down to fewer options in the notebook and fewer epochs
for droprate in droprates:
    print(f'Fitting model for drop rate {droprate}')
    custom_checkpoint = CustomModelCheckpoint(f'{MODELS_DIR}/Mobile_v3_droprate{droprate}_{{epoch:02d}}_{{val_accuracy:.3f}}.keras',
                                save_best_only=False,
                                monitor='val_accuracy',
                                mode='max')    
    model = make_model_Mobile_v3(learning_rate=best_learning_rate, inner_layer_units= best_inner_layer_size, droprate=droprate)
    history = model.fit(train_gen, epochs=15, validation_data=val_gen, callbacks = [custom_checkpoint])
    scores[droprate] = history.history
    print()
    print()
# Out:
# Deleting files previously saved to output directory
#
# Deleted checkpoint file: Mobile_v3_droprate0.0_10_0.841.keras
# Deleted checkpoint file: Mobile_v3_droprate0.2_03_0.831.keras
# Deleted checkpoint file: Mobile_v3_droprate0.0_11_0.842.keras
# Deleted checkpoint file: Mobile_v3_droprate0.1_07_0.841.keras
# Deleted checkpoint file: Mobile_v3_droprate0.2_02_0.822.keras
# Deleted checkpoint file: Mobile_v3_droprate0.0_02_0.816.keras
# Deleted checkpoint file: Mobile_v3_droprate0.05_08_0.839.keras
# Deleted checkpoint file: Mobile_v3_droprate0.2_06_0.842.keras
# Deleted checkpoint file: Mobile_v3_droprate0.0_09_0.840.keras
# Deleted checkpoint file: Mobile_v3_droprate0.0_01_0.801.keras
# Deleted checkpoint file: Mobile_v3_droprate0.1_04_0.828.keras
# Deleted checkpoint file: Mobile_v3_droprate0.2_13_0.846.keras
# Deleted checkpoint file: Mobile_v3_droprate0.1_02_0.820.keras
# Deleted checkpoint file: Mobile_v3_droprate0.0_07_0.836.keras
# Deleted checkpoint file: Mobile_v3_droprate0.05_01_0.801.keras
# Deleted checkpoint file: Mobile_v3_droprate0.2_09_0.845.keras
# Deleted checkpoint file: Mobile_v3_droprate0.2_12_0.846.keras
# Deleted checkpoint file: Mobile_v3_droprate0.05_02_0.819.keras
# Deleted checkpoint file: Mobile_v3_droprate0.1_05_0.838.keras
# Deleted checkpoint file: Mobile_v3_droprate0.2_01_0.795.keras
# Deleted checkpoint file: Mobile_v3_droprate0.2_05_0.838.keras
# Deleted checkpoint file: Mobile_v3_droprate0.0_03_0.828.keras
# Deleted checkpoint file: Mobile_v3_droprate0.2_04_0.834.keras
# Deleted checkpoint file: Mobile_v3_droprate0.0_04_0.831.keras
# Deleted checkpoint file: Mobile_v3_droprate0.1_14_0.844.keras
# Deleted checkpoint file: Mobile_v3_droprate0.1_01_0.798.keras
# Deleted checkpoint file: Mobile_v3_droprate0.05_11_0.844.keras
# Deleted checkpoint file: Mobile_v3_droprate0.1_03_0.825.keras
# Deleted checkpoint file: Mobile_v3_droprate0.0_06_0.832.keras
# Deleted checkpoint file: Mobile_v3_droprate0.1_12_0.842.keras
# Deleted checkpoint file: Mobile_v3_droprate0.05_03_0.832.keras
# Deleted checkpoint file: Mobile_v3_droprate0.05_06_0.839.keras
# Training the model with different dropout rates for the inner layer
#
# Fitting model for drop rate 0.0
# Epoch 1/15
# New best model saved at epoch 1 with validation accuracy 0.803.Filename:../models/Mobile_v3_droprate0.0_01_0.803.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 34s 36ms/step - accuracy: 0.6319 - loss: 1.6157 - val_accuracy: 0.8028 - val_loss: 0.6802
# Epoch 2/15
# New best model saved at epoch 2 with validation accuracy 0.822.Filename:../models/Mobile_v3_droprate0.0_02_0.822.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.8352 - loss: 0.5418 - val_accuracy: 0.8220 - val_loss: 0.5799
# Epoch 3/15
# New best model saved at epoch 3 with validation accuracy 0.827.Filename:../models/Mobile_v3_droprate0.0_03_0.827.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.8789 - loss: 0.3954 - val_accuracy: 0.8272 - val_loss: 0.5488
# Epoch 4/15
# New best model saved at epoch 4 with validation accuracy 0.832.Filename:../models/Mobile_v3_droprate0.0_04_0.832.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.9028 - loss: 0.3055 - val_accuracy: 0.8324 - val_loss: 0.5406
# Epoch 5/15
# New best model saved at epoch 5 with validation accuracy 0.834.Filename:../models/Mobile_v3_droprate0.0_05_0.834.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.9263 - loss: 0.2452 - val_accuracy: 0.8338 - val_loss: 0.5286
# Epoch 6/15
# New best model saved at epoch 6 with validation accuracy 0.837.Filename:../models/Mobile_v3_droprate0.0_06_0.837.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.9412 - loss: 0.2068 - val_accuracy: 0.8368 - val_loss: 0.5292
# Epoch 7/15
# New best model saved at epoch 7 with validation accuracy 0.843.Filename:../models/Mobile_v3_droprate0.0_07_0.843.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.9551 - loss: 0.1666 - val_accuracy: 0.8425 - val_loss: 0.5254
# Epoch 8/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.9615 - loss: 0.1399 - val_accuracy: 0.8372 - val_loss: 0.5401
# Epoch 9/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.9698 - loss: 0.1168 - val_accuracy: 0.8380 - val_loss: 0.5373
# Epoch 10/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9767 - loss: 0.0989 - val_accuracy: 0.8379 - val_loss: 0.5586
# Epoch 11/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9839 - loss: 0.0797 - val_accuracy: 0.8388 - val_loss: 0.5667
# Epoch 12/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9865 - loss: 0.0660 - val_accuracy: 0.8408 - val_loss: 0.5677
# Epoch 13/15
# New best model saved at epoch 13 with validation accuracy 0.843.Filename:../models/Mobile_v3_droprate0.0_13_0.843.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9922 - loss: 0.0514 - val_accuracy: 0.8432 - val_loss: 0.5886
# Epoch 14/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9917 - loss: 0.0463 - val_accuracy: 0.8422 - val_loss: 0.6032
# Epoch 15/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9954 - loss: 0.0361 - val_accuracy: 0.8388 - val_loss: 0.6212
#
#
# Fitting model for drop rate 0.05
# Epoch 1/15
# New best model saved at epoch 1 with validation accuracy 0.799.Filename:../models/Mobile_v3_droprate0.05_01_0.799.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 30s 28ms/step - accuracy: 0.6193 - loss: 1.6376 - val_accuracy: 0.7987 - val_loss: 0.6771
# Epoch 2/15
# New best model saved at epoch 2 with validation accuracy 0.823.Filename:../models/Mobile_v3_droprate0.05_02_0.823.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.8307 - loss: 0.5569 - val_accuracy: 0.8226 - val_loss: 0.5949
# Epoch 3/15
# New best model saved at epoch 3 with validation accuracy 0.828.Filename:../models/Mobile_v3_droprate0.05_03_0.828.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.8691 - loss: 0.4076 - val_accuracy: 0.8281 - val_loss: 0.5503
# Epoch 4/15
# New best model saved at epoch 4 with validation accuracy 0.832.Filename:../models/Mobile_v3_droprate0.05_04_0.832.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.8977 - loss: 0.3198 - val_accuracy: 0.8316 - val_loss: 0.5358
# Epoch 5/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9205 - loss: 0.2606 - val_accuracy: 0.8313 - val_loss: 0.5330
# Epoch 6/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9366 - loss: 0.2165 - val_accuracy: 0.8298 - val_loss: 0.5360
# Epoch 7/15
# New best model saved at epoch 7 with validation accuracy 0.834.Filename:../models/Mobile_v3_droprate0.05_07_0.834.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9448 - loss: 0.1844 - val_accuracy: 0.8340 - val_loss: 0.5391
# Epoch 8/15
# New best model saved at epoch 8 with validation accuracy 0.841.Filename:../models/Mobile_v3_droprate0.05_08_0.841.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9574 - loss: 0.1514 - val_accuracy: 0.8415 - val_loss: 0.5430
# Epoch 9/15
# New best model saved at epoch 9 with validation accuracy 0.843.Filename:../models/Mobile_v3_droprate0.05_09_0.843.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9659 - loss: 0.1277 - val_accuracy: 0.8433 - val_loss: 0.5421
# Epoch 10/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9748 - loss: 0.1039 - val_accuracy: 0.8385 - val_loss: 0.5475
# Epoch 11/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9786 - loss: 0.0902 - val_accuracy: 0.8392 - val_loss: 0.5555
# Epoch 12/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9848 - loss: 0.0735 - val_accuracy: 0.8385 - val_loss: 0.5682
# Epoch 13/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9891 - loss: 0.0609 - val_accuracy: 0.8362 - val_loss: 0.5935
# Epoch 14/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9923 - loss: 0.0502 - val_accuracy: 0.8374 - val_loss: 0.5903
# Epoch 15/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9932 - loss: 0.0424 - val_accuracy: 0.8418 - val_loss: 0.5983
#
#
# Fitting model for drop rate 0.1
# Epoch 1/15
# New best model saved at epoch 1 with validation accuracy 0.791.Filename:../models/Mobile_v3_droprate0.1_01_0.791.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - accuracy: 0.6206 - loss: 1.6383 - val_accuracy: 0.7909 - val_loss: 0.6977
# Epoch 2/15
# New best model saved at epoch 2 with validation accuracy 0.823.Filename:../models/Mobile_v3_droprate0.1_02_0.823.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8215 - loss: 0.5820 - val_accuracy: 0.8228 - val_loss: 0.5780
# Epoch 3/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8647 - loss: 0.4249 - val_accuracy: 0.8195 - val_loss: 0.5626
# Epoch 4/15
# New best model saved at epoch 4 with validation accuracy 0.837.Filename:../models/Mobile_v3_droprate0.1_04_0.837.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.8989 - loss: 0.3248 - val_accuracy: 0.8368 - val_loss: 0.5268
# Epoch 5/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9118 - loss: 0.2801 - val_accuracy: 0.8367 - val_loss: 0.5232
# Epoch 6/15
# New best model saved at epoch 6 with validation accuracy 0.839.Filename:../models/Mobile_v3_droprate0.1_06_0.839.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9313 - loss: 0.2305 - val_accuracy: 0.8395 - val_loss: 0.5341
# Epoch 7/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9422 - loss: 0.1908 - val_accuracy: 0.8385 - val_loss: 0.5353
# Epoch 8/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9541 - loss: 0.1639 - val_accuracy: 0.8386 - val_loss: 0.5275
# Epoch 9/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9619 - loss: 0.1369 - val_accuracy: 0.8354 - val_loss: 0.5390
# Epoch 10/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - accuracy: 0.9709 - loss: 0.1129 - val_accuracy: 0.8372 - val_loss: 0.5570
# Epoch 11/15
# New best model saved at epoch 11 with validation accuracy 0.844.Filename:../models/Mobile_v3_droprate0.1_11_0.844.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9743 - loss: 0.0985 - val_accuracy: 0.8436 - val_loss: 0.5439
# Epoch 12/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9815 - loss: 0.0830 - val_accuracy: 0.8422 - val_loss: 0.5729
# Epoch 13/15
# New best model saved at epoch 13 with validation accuracy 0.844.Filename:../models/Mobile_v3_droprate0.1_13_0.844.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9855 - loss: 0.0705 - val_accuracy: 0.8440 - val_loss: 0.5670
# Epoch 14/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9886 - loss: 0.0591 - val_accuracy: 0.8406 - val_loss: 0.5874
# Epoch 15/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9921 - loss: 0.0494 - val_accuracy: 0.8376 - val_loss: 0.6268
#
#
# Fitting model for drop rate 0.2
# Epoch 1/15
# New best model saved at epoch 1 with validation accuracy 0.793.Filename:../models/Mobile_v3_droprate0.2_01_0.793.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - accuracy: 0.6115 - loss: 1.6929 - val_accuracy: 0.7925 - val_loss: 0.6884
# Epoch 2/15
# New best model saved at epoch 2 with validation accuracy 0.822.Filename:../models/Mobile_v3_droprate0.2_02_0.822.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.8118 - loss: 0.6257 - val_accuracy: 0.8222 - val_loss: 0.5894
# Epoch 3/15
# New best model saved at epoch 3 with validation accuracy 0.826.Filename:../models/Mobile_v3_droprate0.2_03_0.826.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8608 - loss: 0.4495 - val_accuracy: 0.8256 - val_loss: 0.5566
# Epoch 4/15
# New best model saved at epoch 4 with validation accuracy 0.837.Filename:../models/Mobile_v3_droprate0.2_04_0.837.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.8828 - loss: 0.3658 - val_accuracy: 0.8372 - val_loss: 0.5272
# Epoch 5/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9073 - loss: 0.2952 - val_accuracy: 0.8340 - val_loss: 0.5259
# Epoch 6/15
# New best model saved at epoch 6 with validation accuracy 0.840.Filename:../models/Mobile_v3_droprate0.2_06_0.840.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9210 - loss: 0.2603 - val_accuracy: 0.8401 - val_loss: 0.5174
# Epoch 7/15
# New best model saved at epoch 7 with validation accuracy 0.841.Filename:../models/Mobile_v3_droprate0.2_07_0.841.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.9329 - loss: 0.2139 - val_accuracy: 0.8407 - val_loss: 0.5103
# Epoch 8/15
# New best model saved at epoch 8 with validation accuracy 0.844.Filename:../models/Mobile_v3_droprate0.2_08_0.844.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 24s 29ms/step - accuracy: 0.9466 - loss: 0.1815 - val_accuracy: 0.8444 - val_loss: 0.5151
# Epoch 9/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9541 - loss: 0.1568 - val_accuracy: 0.8426 - val_loss: 0.5071
# Epoch 10/15
# New best model saved at epoch 10 with validation accuracy 0.847.Filename:../models/Mobile_v3_droprate0.2_10_0.847.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9609 - loss: 0.1335 - val_accuracy: 0.8468 - val_loss: 0.5143
# Epoch 11/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9688 - loss: 0.1171 - val_accuracy: 0.8458 - val_loss: 0.5327
# Epoch 12/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.9738 - loss: 0.1015 - val_accuracy: 0.8431 - val_loss: 0.5407
# Epoch 13/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9797 - loss: 0.0862 - val_accuracy: 0.8444 - val_loss: 0.5471
# Epoch 14/15
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9835 - loss: 0.0714 - val_accuracy: 0.8424 - val_loss: 0.5517
# Epoch 15/15
# New best model saved at epoch 15 with validation accuracy 0.848.Filename:../models/Mobile_v3_droprate0.2_15_0.848.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9856 - loss: 0.0640 - val_accuracy: 0.8478 - val_loss: 0.5598

# %%
# Plotting the results
plt.figure(figsize=(12, 6))

for droprate in droprates:
    plt.plot(scores[droprate]['val_accuracy'], label=f'Val Accuracy (Drop Rate: {droprate})', linestyle='--')

plt.title('Model Accuracy vs. Dropout Rate for Mobile v3')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
#Plotting training and validation accuracy for dropoutrate=0.2, that seems to be the best
dr=0.2
hist = scores[dr]
plt.figure(figsize=(10, 5))
plt.plot(hist['accuracy'], label=f'Training Accuracy (DR: {dr})')
plt.plot(hist['val_accuracy'], label=f'Validation Accuracy (DR: {dr})')

plt.title(f'Accuracy for Model version 3 with Drop out rate {dr}')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

plt.xticks(np.arange(len(hist['val_accuracy'])), np.arange(1, len(hist['val_accuracy']) + 1))
plt.legend()
plt.grid()
plt.show()

# %%
# Conclusion: The model overfits, but we have an accuracy over 80% afeter just 3-4 epochs

# %%
#Building a summary with the results
best_models_info = {}

for droprate in scores.keys():
    best_val_accuracy = max(scores[droprate]['val_accuracy'])
    
    checkpoint_filename_pattern = f'Mobile_v3_droprate{droprate}_*_{best_val_accuracy:.3f}.keras'
    checkpoint_files = glob.glob(os.path.join(MODELS_DIR, checkpoint_filename_pattern))
    
    if checkpoint_files:
        best_models_info[droprate] = {
            'best_accuracy': best_val_accuracy,
            'checkpoint_file': checkpoint_files[0]  # Get the first matching file
        }
    else:
        print(f"No checkpoint files found for drop rate {droprate} with accuracy {best_val_accuracy:.3f}")

for droprate, info in best_models_info.items():
    print(f"Best model for drop rate {droprate}:")
    print(f"Best Validation Accuracy: {info['best_accuracy']:.3f}")
    print(f"Checkpoint file: {info['checkpoint_file']}")
# Out:
# Best model for drop rate 0.0:
# Best Validation Accuracy: 0.843
# Checkpoint file: ../models/Mobile_v3_droprate0.0_07_0.843.keras
# Best model for drop rate 0.05:
# Best Validation Accuracy: 0.843
# Checkpoint file: ../models/Mobile_v3_droprate0.05_09_0.843.keras
# Best model for drop rate 0.1:
# Best Validation Accuracy: 0.844
# Checkpoint file: ../models/Mobile_v3_droprate0.1_11_0.844.keras
# Best model for drop rate 0.2:
# Best Validation Accuracy: 0.848
# Checkpoint file: ../models/Mobile_v3_droprate0.2_15_0.848.keras

# %%
best_droprate=0.2
print(f"Best Validation Accuracy for 'Mobile version 3' model: {round(best_models_info[best_droprate]['best_accuracy'], 4)}")
print(f"Saved Model File: {best_models_info[best_droprate]['checkpoint_file']}")
# Out:
# Best Validation Accuracy for 'Mobile version 3' model: 0.8478
# Saved Model File: ../models/Mobile_v3_droprate0.2_15_0.848.keras

# %%
scores[0.2]['val_accuracy'][3]
# Out:
# 0.8372171521186829

# %%
## Conclusion: there is not a significant better accuracy by having a version of the model with a dropout layer and the model overfits
epoch=4
epoch_index = epoch-1  #the epochs are 0 indexed
val_accuracy = scores[best_droprate]['val_accuracy'][epoch_index]  
checkpoint_filename = f'Mobile_v3_droprate0.2_{epoch:02d}_{val_accuracy:.3f}.keras'

#verify that the file exists
checkpoint_file_path = os.path.join(MODELS_DIR, checkpoint_filename)

# Check if the file exists
if not os.path.isfile(checkpoint_file_path):
    print(f"Checkpoint file does not exist: {checkpoint_file_path}")
    checkpoint_filename='not found'

#store results for model version 3
model_results['mobile_v3'] = {
    'accuracy': round(val_accuracy, 4),
    'filename': checkpoint_filename
}

# %%
model_results['mobile_v3']
# Out:
# {'accuracy': 0.8372, 'filename': 'Mobile_v3_droprate0.2_04_0.837.keras'}

# %% [markdown]
# ### Training the model Mobile version 3 with augmentation

# %%
#declare a new generator for the train dataset
#the generator for the validation dataset is kept as before, the augmentations are applied to the training dataset only
#(the parameters set here were selected after some experimentation)
train_gen = train_image_gen.flow_from_dataframe(
    dataframe=train_df,
    directory=IMAGES_DIR, 
    x_col='filename',  
    y_col='articleType', 
    target_size=TARGET_SIZE, 
    batch_size=BATCH_SIZE,
    class_mode='categorical',  
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=10,
    zoom_range=0.2,
    horizontal_flip=True,                
    workers = workers,
    use_multiprocessing=use_multiprocessing,
    max_queue_size=MAX_QUEUE_SIZE
)
# Out:
# Found 26649 validated image filenames belonging to 128 classes.

# %%
#check size of images and batches
batch_images, batch_labels = next(train_gen)  
print("Batch shape for training:", batch_images.shape) 
print("Shape of training labels:", batch_labels.shape) 

batch_images, batch_labels = next(val_gen)  
print("Batch shape for validation:", batch_images.shape) 
print("Shape of validation labels:", batch_labels.shape)
# Out:
# Batch shape for training: (32, 96, 96, 3)
# Shape of training labels: (32, 128)
# Batch shape for validation: (32, 96, 96, 3)
# Shape of validation labels: (32, 128)

# %%
#deleting any previous files
print('Deleting files previously saved to output directory\n')
delete_previous_checkpoint_files(r'Mobile_v3_aug.*\.keras')
learning_rate=best_learning_rate
print(f'\nTraining the model with augmentation and learning rate {learning_rate}\n')
#definining a checkpoint to save the model when the accuracy is the max accuracy
custom_checkpoint = CustomModelCheckpoint(f'{MODELS_DIR}/Mobile_v3_aug_{{epoch:02d}}_{{val_accuracy:.3f}}.keras',
                                save_best_only=True,
                                monitor='val_accuracy',
                                mode='max')

model = make_model_Mobile_v1(learning_rate=learning_rate)
history = model.fit(
    train_gen,
    epochs=20,
    validation_data=val_gen,
    callbacks = [custom_checkpoint]
)
# Out:
# Deleting files previously saved to output directory
#
# Deleted checkpoint file: Mobile_v3_aug_07_0.815.keras
# Deleted checkpoint file: Mobile_v3_aug_02_0.759.keras
# Deleted checkpoint file: Mobile_v3_aug_06_0.812.keras
# Deleted checkpoint file: Mobile_v3_aug_01_0.709.keras
# Deleted checkpoint file: Mobile_v3_aug_03_0.782.keras
# Deleted checkpoint file: Mobile_v3_aug_05_0.806.keras
# Deleted checkpoint file: Mobile_v3_aug_04_0.798.keras
# Deleted checkpoint file: Mobile_v3_aug_09_0.824.keras
# Deleted checkpoint file: Mobile_v3_aug_08_0.822.keras
# Deleted checkpoint file: Mobile_v3_aug_15_0.837.keras
# Deleted checkpoint file: Mobile_v3_aug_12_0.831.keras
# Deleted checkpoint file: Mobile_v3_aug_14_0.835.keras
# Deleted checkpoint file: Mobile_v3_aug_10_0.827.keras
# Deleted checkpoint file: Mobile_v3_aug_11_0.831.keras
# Deleted checkpoint file: Mobile_v3_aug_13_0.832.keras
#
# Training the model with augmentation and learning rate 0.0001
#
# Epoch 1/20
# New best model saved at epoch 1 with validation accuracy 0.708.Filename:../models/Mobile_v3_aug_01_0.708.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.3604 - loss: 2.8418 - val_accuracy: 0.7076 - val_loss: 1.0959
# Epoch 2/20
# New best model saved at epoch 2 with validation accuracy 0.759.Filename:../models/Mobile_v3_aug_02_0.759.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.7261 - loss: 0.9735 - val_accuracy: 0.7589 - val_loss: 0.8263
# Epoch 3/20
# New best model saved at epoch 3 with validation accuracy 0.787.Filename:../models/Mobile_v3_aug_03_0.787.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.7826 - loss: 0.7224 - val_accuracy: 0.7866 - val_loss: 0.7219
# Epoch 4/20
# New best model saved at epoch 4 with validation accuracy 0.797.Filename:../models/Mobile_v3_aug_04_0.797.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.8090 - loss: 0.6276 - val_accuracy: 0.7973 - val_loss: 0.6625
# Epoch 5/20
# New best model saved at epoch 5 with validation accuracy 0.808.Filename:../models/Mobile_v3_aug_05_0.808.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.8324 - loss: 0.5447 - val_accuracy: 0.8078 - val_loss: 0.6253
# Epoch 6/20
# New best model saved at epoch 6 with validation accuracy 0.814.Filename:../models/Mobile_v3_aug_06_0.814.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - accuracy: 0.8444 - loss: 0.4938 - val_accuracy: 0.8136 - val_loss: 0.6007
# Epoch 7/20
# New best model saved at epoch 7 with validation accuracy 0.821.Filename:../models/Mobile_v3_aug_07_0.821.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 26s 32ms/step - accuracy: 0.8574 - loss: 0.4564 - val_accuracy: 0.8210 - val_loss: 0.5819
# Epoch 8/20
# New best model saved at epoch 8 with validation accuracy 0.822.Filename:../models/Mobile_v3_aug_08_0.822.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 28ms/step - accuracy: 0.8666 - loss: 0.4224 - val_accuracy: 0.8218 - val_loss: 0.5700
# Epoch 9/20
# New best model saved at epoch 9 with validation accuracy 0.827.Filename:../models/Mobile_v3_aug_09_0.827.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.8803 - loss: 0.3852 - val_accuracy: 0.8270 - val_loss: 0.5560
# Epoch 10/20
# New best model saved at epoch 10 with validation accuracy 0.828.Filename:../models/Mobile_v3_aug_10_0.828.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.8823 - loss: 0.3705 - val_accuracy: 0.8276 - val_loss: 0.5498
# Epoch 11/20
# New best model saved at epoch 11 with validation accuracy 0.830.Filename:../models/Mobile_v3_aug_11_0.830.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.8880 - loss: 0.3571 - val_accuracy: 0.8298 - val_loss: 0.5428
# Epoch 12/20
# New best model saved at epoch 12 with validation accuracy 0.833.Filename:../models/Mobile_v3_aug_12_0.833.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.8980 - loss: 0.3305 - val_accuracy: 0.8332 - val_loss: 0.5378
# Epoch 13/20
# New best model saved at epoch 13 with validation accuracy 0.836.Filename:../models/Mobile_v3_aug_13_0.836.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.8992 - loss: 0.3225 - val_accuracy: 0.8356 - val_loss: 0.5342
# Epoch 14/20
# New best model saved at epoch 14 with validation accuracy 0.837.Filename:../models/Mobile_v3_aug_14_0.837.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.9043 - loss: 0.3086 - val_accuracy: 0.8368 - val_loss: 0.5311
# Epoch 15/20
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.9080 - loss: 0.2986 - val_accuracy: 0.8354 - val_loss: 0.5307
# Epoch 16/20
# New best model saved at epoch 16 with validation accuracy 0.838.Filename:../models/Mobile_v3_aug_16_0.838.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.9101 - loss: 0.2901 - val_accuracy: 0.8378 - val_loss: 0.5269
# Epoch 17/20
# New best model saved at epoch 17 with validation accuracy 0.839.Filename:../models/Mobile_v3_aug_17_0.839.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 28ms/step - accuracy: 0.9134 - loss: 0.2765 - val_accuracy: 0.8387 - val_loss: 0.5242
# Epoch 18/20
# New best model saved at epoch 18 with validation accuracy 0.839.Filename:../models/Mobile_v3_aug_18_0.839.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.9176 - loss: 0.2715 - val_accuracy: 0.8394 - val_loss: 0.5263
# Epoch 19/20
# New best model saved at epoch 19 with validation accuracy 0.840.Filename:../models/Mobile_v3_aug_19_0.840.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 28ms/step - accuracy: 0.9210 - loss: 0.2565 - val_accuracy: 0.8398 - val_loss: 0.5260
# Epoch 20/20
# New best model saved at epoch 20 with validation accuracy 0.840.Filename:../models/Mobile_v3_aug_20_0.840.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 24s 29ms/step - accuracy: 0.9207 - loss: 0.2489 - val_accuracy: 0.8404 - val_loss: 0.5271

# %%
#Plotting train and validation accuracy
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')

plt.title('Accuracy for Model Mobile v3 trained with Augmentation')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

num_epochs = len(history.history['val_accuracy'])  
plt.xticks(np.arange(num_epochs), np.arange(1, num_epochs + 1)) 
plt.legend()
plt.grid()
plt.show()

# %%
##Conclusion, the model does not overfit and have an accuracy over 83% for the validation dataset

# %%
model_results['mobile_v3_with_augmentation'] = {
    'accuracy': round(custom_checkpoint.best_accuracy, 4),
    'filename': custom_checkpoint.best_model_file
}
print(f"Best Validation Accuracy for 'Mobile version 3 with Augmentation' model: {model_results['mobile_v3_with_augmentation']['accuracy']}")
print(f"Saved Model File: {model_results['mobile_v3_with_augmentation']['filename']}")
# Out:
# Best Validation Accuracy for 'Mobile version 3 with Augmentation' model: 0.8404
# Saved Model File: ../models/Mobile_v3_aug_20_0.840.keras

# %% [markdown]
# ### Using the model Mobile version 1 trained with augmentation

# %%
#deleting any previous files
print('Deleting files previously saved to output directory\n')
delete_previous_checkpoint_files(r'Mobile_v1_aug.*\.keras')
learning_rate=best_learning_rate
print(f'\nTraining the model with augmentation and learning rate {learning_rate}\n')
#definining a checkpoint to save the model when the accuracy is the max accuracy
custom_checkpoint = CustomModelCheckpoint(f'{MODELS_DIR}/Mobile_v1_aug_{{epoch:02d}}_{{val_accuracy:.3f}}.keras',
                                save_best_only=True,
                                monitor='val_accuracy',
                                mode='max')

model = make_model_Mobile_v1(learning_rate=learning_rate)
history = model.fit(
    train_gen,
    epochs=20,
    validation_data=val_gen,
    callbacks = [custom_checkpoint]
)
# Out:
# Deleting files previously saved to output directory
#
# Deleted checkpoint file: Mobile_v1_aug_05_0.807.keras
# Deleted checkpoint file: Mobile_v1_aug_11_0.831.keras
# Deleted checkpoint file: Mobile_v1_aug_15_0.837.keras
# Deleted checkpoint file: Mobile_v1_aug_09_0.826.keras
# Deleted checkpoint file: Mobile_v1_aug_03_0.781.keras
# Deleted checkpoint file: Mobile_v1_aug_13_0.833.keras
# Deleted checkpoint file: Mobile_v1_aug_10_0.826.keras
# Deleted checkpoint file: Mobile_v1_aug_01_0.711.keras
# Deleted checkpoint file: Mobile_v1_aug_06_0.813.keras
# Deleted checkpoint file: Mobile_v1_aug_07_0.818.keras
# Deleted checkpoint file: Mobile_v1_aug_04_0.798.keras
# Deleted checkpoint file: Mobile_v1_aug_08_0.825.keras
# Deleted checkpoint file: Mobile_v1_aug_12_0.831.keras
# Deleted checkpoint file: Mobile_v1_aug_02_0.765.keras
#
# Training the model with augmentation and learning rate 0.0001
#
# Epoch 1/20
# New best model saved at epoch 1 with validation accuracy 0.712.Filename:../models/Mobile_v1_aug_01_0.712.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 27s 26ms/step - accuracy: 0.3704 - loss: 2.8352 - val_accuracy: 0.7125 - val_loss: 1.0747
# Epoch 2/20
# New best model saved at epoch 2 with validation accuracy 0.763.Filename:../models/Mobile_v1_aug_02_0.763.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.7341 - loss: 0.9659 - val_accuracy: 0.7633 - val_loss: 0.8202
# Epoch 3/20
# New best model saved at epoch 3 with validation accuracy 0.788.Filename:../models/Mobile_v1_aug_03_0.788.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.7774 - loss: 0.7382 - val_accuracy: 0.7882 - val_loss: 0.7188
# Epoch 4/20
# New best model saved at epoch 4 with validation accuracy 0.801.Filename:../models/Mobile_v1_aug_04_0.801.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.8060 - loss: 0.6271 - val_accuracy: 0.8005 - val_loss: 0.6626
# Epoch 5/20
# New best model saved at epoch 5 with validation accuracy 0.809.Filename:../models/Mobile_v1_aug_05_0.809.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.8294 - loss: 0.5572 - val_accuracy: 0.8087 - val_loss: 0.6247
# Epoch 6/20
# New best model saved at epoch 6 with validation accuracy 0.812.Filename:../models/Mobile_v1_aug_06_0.812.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.8425 - loss: 0.5042 - val_accuracy: 0.8125 - val_loss: 0.6037
# Epoch 7/20
# New best model saved at epoch 7 with validation accuracy 0.819.Filename:../models/Mobile_v1_aug_07_0.819.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.8581 - loss: 0.4550 - val_accuracy: 0.8188 - val_loss: 0.5815
# Epoch 8/20
# New best model saved at epoch 8 with validation accuracy 0.823.Filename:../models/Mobile_v1_aug_08_0.823.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.8675 - loss: 0.4264 - val_accuracy: 0.8230 - val_loss: 0.5681
# Epoch 9/20
# New best model saved at epoch 9 with validation accuracy 0.825.Filename:../models/Mobile_v1_aug_09_0.825.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 30s 36ms/step - accuracy: 0.8750 - loss: 0.4021 - val_accuracy: 0.8247 - val_loss: 0.5578
# Epoch 10/20
# New best model saved at epoch 10 with validation accuracy 0.829.Filename:../models/Mobile_v1_aug_10_0.829.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.8856 - loss: 0.3757 - val_accuracy: 0.8294 - val_loss: 0.5526
# Epoch 11/20
# New best model saved at epoch 11 with validation accuracy 0.831.Filename:../models/Mobile_v1_aug_11_0.831.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 24s 29ms/step - accuracy: 0.8894 - loss: 0.3555 - val_accuracy: 0.8311 - val_loss: 0.5446
# Epoch 12/20
# New best model saved at epoch 12 with validation accuracy 0.832.Filename:../models/Mobile_v1_aug_12_0.832.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.8955 - loss: 0.3395 - val_accuracy: 0.8318 - val_loss: 0.5388
# Epoch 13/20
# New best model saved at epoch 13 with validation accuracy 0.834.Filename:../models/Mobile_v1_aug_13_0.834.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.8999 - loss: 0.3194 - val_accuracy: 0.8338 - val_loss: 0.5372
# Epoch 14/20
# New best model saved at epoch 14 with validation accuracy 0.835.Filename:../models/Mobile_v1_aug_14_0.835.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.8999 - loss: 0.3177 - val_accuracy: 0.8346 - val_loss: 0.5312
# Epoch 15/20
# New best model saved at epoch 15 with validation accuracy 0.835.Filename:../models/Mobile_v1_aug_15_0.835.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9086 - loss: 0.2936 - val_accuracy: 0.8351 - val_loss: 0.5318
# Epoch 16/20
# New best model saved at epoch 16 with validation accuracy 0.839.Filename:../models/Mobile_v1_aug_16_0.839.keras
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - accuracy: 0.9115 - loss: 0.2847 - val_accuracy: 0.8388 - val_loss: 0.5288
# Epoch 17/20
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - accuracy: 0.9116 - loss: 0.2824 - val_accuracy: 0.8385 - val_loss: 0.5287
# Epoch 18/20
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.9172 - loss: 0.2650 - val_accuracy: 0.8374 - val_loss: 0.5268
# Epoch 19/20
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.9213 - loss: 0.2551 - val_accuracy: 0.8372 - val_loss: 0.5331
# Epoch 20/20
# 833/833 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9197 - loss: 0.2557 - val_accuracy: 0.8373 - val_loss: 0.5283

# %%
#Plotting train and validation accuracy
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')

plt.title('Accuracy for Model Mobile v1 trained with Augmentation')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')

num_epochs = len(history.history['val_accuracy'])  
plt.xticks(np.arange(num_epochs), np.arange(1, num_epochs + 1)) 
plt.legend()
plt.grid()
plt.show()

# %%
## Conclusion: by using augmentation to train model 1, we get results very similar than those for the version 3 of the model which includes more layers

# %%
model_results['mobile_v1_with_augmentation'] = {
    'accuracy': round(custom_checkpoint.best_accuracy, 4),
    'filename': custom_checkpoint.best_model_file
}
print(f"Best Validation Accuracy for 'Mobile version 3 with Augmentation' model: {model_results['mobile_v1_with_augmentation']['accuracy']}")
print(f"Saved Model File: {model_results['mobile_v1_with_augmentation']['filename']}")
# Out:
# Best Validation Accuracy for 'Mobile version 3 with Augmentation' model: 0.8388
# Saved Model File: ../models/Mobile_v1_aug_16_0.839.keras

# %%
# Display all results
print("Model Evaluation Results:\n")
for model_name, results in model_results.items():
    print(f"Model: {model_name}")
    print(f"  Best Validation Accuracy: {results['accuracy']}")
    print(f"  Checkpoint File: {results['filename']}")
    print()  # Print a newline for better readability
# Out:
# Model Evaluation Results:
#
# Model: mobile_v1
#   Best Validation Accuracy: 0.8024
#   Checkpoint File: Mobile_v1_05_0.802.keras
#
# Model: mobile_v2
#   Best Validation Accuracy: 0.8201
#   Checkpoint File: Mobile_v2_size1280_02_0.820.keras
#
# Model: mobile_v3
#   Best Validation Accuracy: 0.8372
#   Checkpoint File: Mobile_v3_droprate0.2_04_0.837.keras
#
# Model: mobile_v3_with_augmentation
#   Best Validation Accuracy: 0.8404
#   Checkpoint File: ../models/Mobile_v3_aug_20_0.840.keras
#
# Model: mobile_v4_with_augmentation
#   Best Validation Accuracy: 0.8388
#   Checkpoint File: ../models/Mobile_v1_aug_16_0.839.keras
#
# Model: mobile_v1_with_augmentation
#   Best Validation Accuracy: 0.8388
#   Checkpoint File: ../models/Mobile_v1_aug_16_0.839.keras

# %%
#Conclusion: after all the training, I will go with the version 1 of the model, trained with augmentation for 16 epochs

# %%
# Calculate time it took to run the notebook
end_time = time.time()
total_time_seconds = end_time - start_time
total_time_minutes = round(total_time_seconds / 60)

print(f"Total execution time for this notebook: {total_time_minutes} minutes")
